# %%
import os
import re
import numpy as np
import tifffile as tiff
import cv2
from skimage import io
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def process_images(input_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    
    pattern = re.compile(r'(.+)-F([4-9]|10|11)')  # Match files with -F4 to -F11
    
    for filename in os.listdir(input_folder):
        if not filename.endswith(".tif") or not pattern.match(filename):
            continue
        
        input_path = os.path.join(input_folder, filename)
        with tiff.TiffFile(input_path) as tif_file:
            img = tif_file.asarray()
            print(f"The dimensions of the input image are {img.shape}")
            metadata = tif_file.pages[0].tags
            resolution_tag = metadata.get('XResolution')
            z_resolution_tag = metadata.get('ZResolution')
            pixel_size = 0.1883734  # Default XY pixel size
            z_pixel_size = 1.0  # Default Z pixel size
            
            if resolution_tag:
                resolution = resolution_tag.value
                pixel_size = resolution[1] / resolution[0]
            
            if z_resolution_tag:
                z_resolution = z_resolution_tag.value
                z_pixel_size = z_resolution[1] / z_resolution[0]
        
        if len(img.shape) == 4 and img.shape[1] == 4:  # (Z, C, H, W)
            img = np.moveaxis(img, 1, 0)  # (C, Z, H, W)
            print(f"The dimensions of the image after np.moveaxis: {img.shape}")
            ch3_proj = np.max(img[2], axis = 0)  # Max project Ch3 (PhosphoH3)
            
            _, thresh = cv2.threshold(ch3_proj, 0, 255, cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            objects = sorted(contours, key = cv2.contourArea, reverse=True)[:2]  # Get up to 2 largest objects
            
            for idx, cnt in enumerate(objects):
                x, y, w, h = cv2.boundingRect(cnt)
                center_x, center_y = x + w // 2, y + h // 2
                
                half_size = 75  # 150x150 crop
                x1, x2 = center_x - half_size, center_x + half_size
                y1, y2 = center_y - half_size, center_y + half_size
                
                pad_x1, pad_x2, pad_y1, pad_y2 = 0, 0, 0, 0
                if x1 < 0:
                    pad_x1 = abs(x1)
                    x1 = 0
                if x2 > img.shape[3]:
                    pad_x2 = x2 - img.shape[3]
                    x2 = img.shape[3]
                if y1 < 0:
                    pad_y1 = abs(y1)
                    y1 = 0
                if y2 > img.shape[2]:
                    pad_y2 = y2 - img.shape[2]
                    y2 = img.shape[2]
                
                cropped_ch2 = img[1, :, y1:y2, x1:x2] #CZYX Tubulin (ch2)
                cropped_ch3 = img[0, :, y1:y2, x1:x2] #CZYX Dapi (ch1)

                print(f"Shape of cropped_ch2 before padding: {cropped_ch2.shape}")
                print(f"Shape of cropped_ch3 before padding: {cropped_ch3.shape}")
                
                cropped_ch2 = np.pad(cropped_ch2, ((0, 0), (pad_y1, pad_y2), (pad_x1, pad_x2)), mode = 'constant', constant_values = 0)
                cropped_ch3 = np.pad(cropped_ch3, ((0, 0), (pad_y1, pad_y2), (pad_x1, pad_x2)), mode = 'constant', constant_values = 0)
                
                cropped_ch2 = np.pad(cropped_ch2, ((1, 1), (0, 0), (0, 0)), mode = 'constant', constant_values = 0)  # Add empty Z slices
                cropped_ch3 = np.pad(cropped_ch3, ((1, 1), (0, 0), (0, 0)), mode = 'constant', constant_values = 0)  # Add empty Z slices

                print(f"Shape of cropped_ch2: {cropped_ch2.shape}")
                print(f"Shape of cropped_ch3: {cropped_ch3.shape}")
                
                # Stack channels together in (Z, C, Y, X) format
                cropped_stack = np.stack([cropped_ch2, cropped_ch3], axis = 1)  # (Z, C, Y, X)
                cropped_stack = np.expand_dims(cropped_stack, axis = 0) # (T, Z, C, Y, X)
                                
                print(f"Shape of cropped_stack after merging and expansion: {cropped_stack.shape}")
                
                output_filename = os.path.join(output_folder, f"{filename.replace('.tif', '')}_obj{idx+1}_crop.tif")


                tiff.imwrite(
                    output_filename, 
                    cropped_stack, 
                    imagej = True,
                    metadata = {
                        'spacing': z_pixel_size, #This is hardcoded for now, TODO read from imput!
                        'unit': 'um',
                        'axes': 'TZCYX'
                    },
                    resolution = (1.0 / pixel_size, 1.0 / pixel_size)
                )
                print(f"Saved: {output_filename}")
    print("Done.")

# %%
input_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/01_Importer"
output_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi"
process_images(input_folder, output_folder)
# Out:
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C04-F8_D4_IM_CALM1_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C04-F9_D4_IM_CALM1_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C04-F10_D4_IM_CALM1_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 88)
# Shape of cropped_ch3 before padding: (16, 150, 88)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C04-F10_D4_IM_CALM1_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C04-F11_D4_IM_CALM1_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F4_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F5_B3_IM_KIF11_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F5_B3_IM_KIF11_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F6_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F7_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F8_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F9_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F10_B3_IM_KIF11_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F11_B3_IM_KIF11_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C03-F11_B3_IM_KIF11_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F4_B4_IM_ANAPC11_new_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F5_B4_IM_ANAPC11_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F5_B4_IM_ANAPC11_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F6_B4_IM_ANAPC11_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F6_B4_IM_ANAPC11_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F7_B4_IM_ANAPC11_new_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F8_B4_IM_ANAPC11_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 113)
# Shape of cropped_ch3 before padding: (16, 150, 113)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F8_B4_IM_ANAPC11_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F9_B4_IM_ANAPC11_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F9_B4_IM_ANAPC11_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F10_B4_IM_ANAPC11_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F10_B4_IM_ANAPC11_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C04-F11_B4_IM_ANAPC11_new_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F4_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 127, 150)
# Shape of cropped_ch3 before padding: (16, 127, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F4_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F5_B5_IM_APC_new_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F6_B5_IM_APC_new_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F7_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F7_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F8_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F8_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F9_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F9_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F10_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F10_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F11_B5_IM_APC_new_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C05-F11_B5_IM_APC_new_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F4_B6_IM_ASPM_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F5_B6_IM_ASPM_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F6_B6_IM_ASPM_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F7_B6_IM_ASPM_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F7_B6_IM_ASPM_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F8_B6_IM_ASPM_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F8_B6_IM_ASPM_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F9_B6_IM_ASPM_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F10_B6_IM_ASPM_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 115)
# Shape of cropped_ch3 before padding: (16, 150, 115)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F10_B6_IM_ASPM_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F11_B6_IM_ASPM_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 135, 88)
# Shape of cropped_ch3 before padding: (16, 135, 88)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C06-F11_B6_IM_ASPM_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F4_B7_CM_CENPJ_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F5_B7_CM_CENPJ_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F6_B7_CM_CENPJ_init_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F4_B8_CM_CENPI_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 137)
# Shape of cropped_ch3 before padding: (16, 150, 137)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F4_B8_CM_CENPI_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F5_B8_CM_CENPI_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F5_B8_CM_CENPI_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F6_B8_CM_CENPI_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F6_B8_CM_CENPI_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F7_B8_CM_CENPI_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F8_B8_CM_CENPI_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F8_B8_CM_CENPI_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F9_B8_CM_CENPI_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F10_B8_CM_CENPI_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F4_B10_CM_CENPE_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F4_B10_CM_CENPE_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F5_B10_CM_CENPE_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F6_B10_CM_CENPE_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F6_B10_CM_CENPE_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F7_B10_CM_CENPE_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F7_B10_CM_CENPE_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F4_B11_CM_CENPC_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F5_B11_CM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F5_B11_CM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F6_B11_CM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F6_B11_CM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F7_B11_CM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F7_B11_CM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 126)
# Shape of cropped_ch3 before padding: (16, 150, 126)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F8_B11_CM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F8_B11_CM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F9_B11_CM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F9_B11_CM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F4_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F5_C2_IM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F5_C2_IM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F6_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F7_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F8_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F9_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C02-F10_C2_IM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# ...
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C09-F10_F9_CM_AURKC_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C09-F10_F9_CM_AURKC_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C09-F11_F9_CM_AURKC_init_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C09-F11_F9_CM_AURKC_init_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F4_F10_CM_AURKB_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 96)
# Shape of cropped_ch3 before padding: (16, 150, 96)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F4_F10_CM_AURKB_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F5_F10_CM_AURKB_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F5_F10_CM_AURKB_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F6_F10_CM_AURKB_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F7_F10_CM_AURKB_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F8_F10_CM_AURKB_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F8_F10_CM_AURKB_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F9_F10_CM_AURKB_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F10_F10_CM_AURKB_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C10-F11_F10_CM_AURKB_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F4_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F4_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F5_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F5_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F6_F11_CM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F7_F11_CM_AURKA_orig_obj1_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F8_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F8_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F9_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F9_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F10_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F10_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F11_F11_CM_AURKA_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C11-F11_F11_CM_AURKA_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C02-F4_G2_IM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C02-F4_G2_IM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C02-F5_G2_IM_CENPC_orig_obj1_crop.tif
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C02-F5_G2_IM_CENPC_orig_obj2_crop.tif
# The dimensions of the input image are (16, 4, 1080, 1080)
# The dimensions of the image after np.moveaxis: (4, 16, 1080, 1080)
# Shape of cropped_ch2 before padding: (16, 150, 150)
# Shape of cropped_ch3 before padding: (16, 150, 150)
# Shape of cropped_ch2: (18, 150, 150)
# Shape of cropped_ch3: (18, 150, 150)
# Shape of cropped_stack after merging and expansion: (1, 18, 2, 150, 150)
# Saved: /Volumes/arxivBeta/_Tobias/Opera/20250204/04_Crop_Dapi/ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C02-F6_G2_IM_CENPC_orig_obj1_crop.tif
# Done.
