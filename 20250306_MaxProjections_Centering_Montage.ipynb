# %%
import os
import re
import numpy as np
import tifffile as tiff
import cv2

# %%
def max_projection_montage(input_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists
    
    # Regex to match files containing '-F4' to '-F11'
    pattern = re.compile(r'-F([4-9]|10|11)')
    
    for filename in os.listdir(input_folder):
        if filename.endswith(".tif") and pattern.search(filename):
            input_path = os.path.join(input_folder, filename)
            
            # Read multi-dimensional TIF file with metadata
            with tiff.TiffFile(input_path) as tif_file:
                img = tif_file.asarray()
                metadata = tif_file.pages[0].tags
                resolution_tag = metadata.get('XResolution')  # Get resolution if available
                pixel_size = 0.1883734  # Default pixel size in microns
                if resolution_tag:
                    resolution = resolution_tag.value  # Extract actual value
                    pixel_size = resolution[1] / resolution[0]  # Convert to microns per pixel
            
            print(f"Processing {filename} with shape {img.shape}")
            
            # Ensure image has correct dimensions (Z, C, H, W) or (C, Z, H, W)
            if len(img.shape) == 4:
                if img.shape[1] == 4:  # (Z, C, H, W) format
                    img = np.moveaxis(img, 1, 0)  # Convert to (C, Z, H, W)
                
                # Now img is (C, Z, H, W)
                channels = [np.max(img[i, :, :, :], axis=0) for i in range(4)]
                
                # Debug: Print max intensity per channel
                for i, ch in enumerate(channels):
                    print(f"Channel {i} max intensity: {np.max(ch)}")
                
                # Find the brightest object in channel 3 (index 2)
                ch3 = channels[2]
                min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(ch3)
                center_x, center_y = max_loc
                print(f"Channel 3 max value: {max_val} at {max_loc}")
                
                if max_val == 0:
                    print(f"Skipping {filename}: No bright object found in channel 3.")
                    continue
                
                # Define cropping bounds (400x400 pixels around the brightest object)
                half_size = 200
                h, w = ch3.shape
                x1, x2 = center_x - half_size, center_x + half_size
                y1, y2 = center_y - half_size, center_y + half_size
                
                # Ensure crop remains within image bounds and pad if necessary
                pad_x1, pad_x2, pad_y1, pad_y2 = 0, 0, 0, 0
                if x1 < 0:
                    pad_x1 = abs(x1)
                    x1 = 0
                if x2 > w:
                    pad_x2 = x2 - w
                    x2 = w
                if y1 < 0:
                    pad_y1 = abs(y1)
                    y1 = 0
                if y2 > h:
                    pad_y2 = y2 - h
                    y2 = h
                
                print(f"Cropping coordinates: x1={x1}, x2={x2}, y1={y1}, y2={y2}")
                print(f"Padding applied: Left={pad_x1}, Right={pad_x2}, Top={pad_y1}, Bottom={pad_y2}")
                
                # Crop and pad each channel at the same position
                cropped_channels = [ch[y1:y2, x1:x2] for ch in channels]
                padded_channels = [
                    cv2.copyMakeBorder(ch, pad_y1, pad_y2, pad_x1, pad_x2, cv2.BORDER_CONSTANT, value=0)
                    for ch in cropped_channels
                ]
                
                # Normalize each channel to grayscale (0-255)
                def safe_normalize(img):
                    if np.max(img) == np.min(img):  # Avoid division by zero
                        return np.zeros_like(img, dtype=np.uint8)
                    return cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
                
                grayscale_channels = [safe_normalize(ch) for ch in padded_channels]
                
                # Arrange in a 2x2 montage
                top_row = np.hstack((grayscale_channels[0], grayscale_channels[1]))
                bottom_row = np.hstack((grayscale_channels[2], grayscale_channels[3]))
                montage = np.vstack((top_row, bottom_row))
                
                # Preserve metadata and pixel calibration
                with tiff.TiffWriter(os.path.join(output_folder, filename)) as tif:
                    tif.write(montage, metadata = {'axes': 'YX'}, resolution = (1.0 / pixel_size, 1.0 / pixel_size))
                
                print(f'Processed: {filename}')
            else:
                print(f'Skipping {filename}: Unexpected image dimensions {img.shape}')
    print("Done.")

# %%
input_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/Importer_cases"  # Change this to your actual folder path
output_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/Montages_cases_V2"  # Change this to your actual output folder path
#input_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/In"  # Change this to your actual folder path
#output_folder = "/Volumes/arxivBeta/_Tobias/Opera/20250204/Out"  # Change this to your actual output folder path

max_projection_montage(input_folder, output_folder)
# Out:
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F7_B7_CM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F7_B7_CM_CENPJ_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F8_B7_CM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F8_B7_CM_CENPJ_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F9_B7_CM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F9_B7_CM_CENPJ_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F10_B7_CM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F10_B7_CM_CENPJ_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F11_B7_CM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C07-F11_B7_CM_CENPJ_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F11_B8_CM_CENPI_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C08-F11_B8_CM_CENPI_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F4_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F4_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F5_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F5_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F6_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F6_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F7_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F7_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F8_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F8_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F9_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F9_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F10_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F10_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F11_B9_CM_CENPF_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C09-F11_B9_CM_CENPF_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F8_B10_CM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F8_B10_CM_CENPE_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F9_B10_CM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F9_B10_CM_CENPE_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F10_B10_CM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F10_B10_CM_CENPE_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F11_B10_CM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C10-F11_B10_CM_CENPE_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F8_B11_CM_CENPC_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 40286
# Channel 1 max intensity: 25169
# Channel 2 max intensity: 25475
# Channel 3 max intensity: 31493
# Channel 3 max value: 25475.0 at (1023, 258)
# Cropping coordinates: x1=823, x2=1080, y1=58, y2=458
# Padding applied: Left=0, Right=143, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F8_B11_CM_CENPC_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F10_B11_CM_CENPC_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F10_B11_CM_CENPC_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F11_B11_CM_CENPC_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R02-C11-F11_B11_CM_CENPC_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C03-F8_C3_IM_AURKB_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 22238
# Channel 1 max intensity: 26477
# Channel 2 max intensity: 31484
# Channel 3 max intensity: 46658
# Channel 3 max value: 31484.0 at (797, 156)
# Cropping coordinates: x1=597, x2=997, y1=0, y2=356
# Padding applied: Left=0, Right=0, Top=44, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C03-F8_C3_IM_AURKB_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C04-F8_C4_IM_AURKC_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 25607
# Channel 1 max intensity: 31520
# Channel 2 max intensity: 28803
# Channel 3 max intensity: 40029
# Channel 3 max value: 28803.0 at (900, 917)
# Cropping coordinates: x1=700, x2=1080, y1=717, y2=1080
# Padding applied: Left=0, Right=20, Top=0, Bottom=37
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C04-F8_C4_IM_AURKC_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F9_C7_CM_CDK5RAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F9_C7_CM_CDK5RAP2_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F10_C7_CM_CDK5RAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F10_C7_CM_CDK5RAP2_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F11_C7_CM_CDK5RAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C07-F11_C7_CM_CDK5RAP2_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F9_C8_CM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F9_C8_CM_CDK1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F10_C8_CM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F10_C8_CM_CDK1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F11_C8_CM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C08-F11_C8_CM_CDK1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C09-F11_C9_CM_CDCA8_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C09-F11_C9_CM_CDCA8_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C10-F10_C10_CM_CDC42_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C10-F10_C10_CM_CDC42_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C10-F11_C10_CM_CDC42_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C10-F11_C10_CM_CDC42_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F4_C11_CM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 53849
# Channel 1 max intensity: 35685
# Channel 2 max intensity: 23662
# Channel 3 max intensity: 33719
# Channel 3 max value: 23662.0 at (1060, 740)
# Cropping coordinates: x1=860, x2=1080, y1=540, y2=940
# Padding applied: Left=0, Right=180, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F4_C11_CM_CDC34_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F9_C11_CM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F9_C11_CM_CDC34_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F10_C11_CM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F10_C11_CM_CDC34_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F11_C11_CM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R03-C11-F11_C11_CM_CDC34_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C08-F11_D8_CM_CDC20_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C08-F11_D8_CM_CDC20_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F5_D9_CM_CDC16_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 39587
# Channel 1 max intensity: 14804
# Channel 2 max intensity: 27002
# Channel 3 max intensity: 33651
# Channel 3 max value: 27002.0 at (327, 35)
# Cropping coordinates: x1=127, x2=527, y1=0, y2=235
# Padding applied: Left=0, Right=0, Top=165, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F5_D9_CM_CDC16_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F8_D9_CM_CDC16_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F8_D9_CM_CDC16_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F9_D9_CM_CDC16_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F9_D9_CM_CDC16_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F10_D9_CM_CDC16_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F10_D9_CM_CDC16_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F11_D9_CM_CDC16_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C09-F11_D9_CM_CDC16_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C10-F10_D10_CM_CCNB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C10-F10_D10_CM_CCNB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C10-F11_D10_CM_CCNB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C10-F11_D10_CM_CCNB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C02-F9_E2_IM_CAMSAP3_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 25663
# Channel 1 max intensity: 23112
# Channel 2 max intensity: 42870
# Channel 3 max intensity: 60356
# Channel 3 max value: 42870.0 at (928, 352)
# Cropping coordinates: x1=728, x2=1080, y1=152, y2=552
# Padding applied: Left=0, Right=48, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C02-F9_E2_IM_CAMSAP3_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C07-F9_E7_CM_CAMSAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 20389
# Channel 1 max intensity: 19888
# Channel 2 max intensity: 1967
# Channel 3 max intensity: 11579
# Channel 3 max value: 1967.0 at (244, 91)
# Cropping coordinates: x1=44, x2=444, y1=0, y2=291
# Padding applied: Left=0, Right=0, Top=109, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C07-F9_E7_CM_CAMSAP2_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C07-F10_E7_CM_CAMSAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 13746
# Channel 1 max intensity: 5400
# Channel 2 max intensity: 21233
# Channel 3 max intensity: 25612
# Channel 3 max value: 21233.0 at (543, 167)
# Cropping coordinates: x1=343, x2=743, y1=0, y2=367
# Padding applied: Left=0, Right=0, Top=33, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C07-F10_E7_CM_CAMSAP2_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F9_E8_CM_CAMSAP1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F9_E8_CM_CAMSAP1_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F10_E8_CM_CAMSAP1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F10_E8_CM_CAMSAP1_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F11_E8_CM_CAMSAP1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C08-F11_E8_CM_CAMSAP1_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C09-F11_E9_CM_CALM1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C09-F11_E9_CM_CALM1_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F6_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F6_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F7_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F7_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F8_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F8_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F9_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F9_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F10_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F10_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F11_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R05-C11-F11_E11_CM_BUB1B_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C03-F6_F3_IM_CDC42_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 19402
# Channel 1 max intensity: 21642
# Channel 2 max intensity: 39237
# Channel 3 max intensity: 49964
# Channel 3 max value: 39237.0 at (194, 601)
# Cropping coordinates: x1=0, x2=394, y1=401, y2=801
# Padding applied: Left=6, Right=0, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C03-F6_F3_IM_CDC42_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C03-F7_F3_IM_CDC42_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 19511
# Channel 1 max intensity: 28097
# Channel 2 max intensity: 37233
# Channel 3 max intensity: 51313
# Channel 3 max value: 37233.0 at (964, 200)
# Cropping coordinates: x1=764, x2=1080, y1=0, y2=400
# Padding applied: Left=0, Right=84, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C03-F7_F3_IM_CDC42_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C05-F5_F5_IM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 22127
# Channel 1 max intensity: 27039
# Channel 2 max intensity: 29039
# Channel 3 max intensity: 43703
# Channel 3 max value: 29039.0 at (894, 151)
# Cropping coordinates: x1=694, x2=1080, y1=0, y2=351
# Padding applied: Left=0, Right=14, Top=49, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C05-F5_F5_IM_CDK1_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C05-F8_F5_IM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 19309
# Channel 1 max intensity: 29663
# Channel 2 max intensity: 38868
# Channel 3 max intensity: 53363
# Channel 3 max value: 38868.0 at (501, 26)
# Cropping coordinates: x1=301, x2=701, y1=0, y2=226
# Padding applied: Left=0, Right=0, Top=174, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C05-F8_F5_IM_CDK1_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F8_F7_CM_BUB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F8_F7_CM_BUB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F9_F7_CM_BUB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F9_F7_CM_BUB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F10_F7_CM_BUB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F10_F7_CM_BUB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F11_F7_CM_BUB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C07-F11_F7_CM_BUB1_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F6_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F6_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F7_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F7_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F8_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F8_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F9_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F9_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F10_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F10_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F11_G7_CM_ASPM_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C07-F11_G7_CM_ASPM_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C08-F10_G8_CM_APC_new.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C08-F10_G8_CM_APC_new.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C08-F11_G8_CM_APC_new.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C08-F11_G8_CM_APC_new.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C09-F10_G9_CM_ANAPC11_new.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C09-F10_G9_CM_ANAPC11_new.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C09-F11_G9_CM_ANAPC11_new.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C09-F11_G9_CM_ANAPC11_new.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C11-F11_G11_CM_LUC1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R07-C11-F11_G11_CM_LUC1_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C03-F4_B3_IM_KIF11_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 27061
# Channel 1 max intensity: 61603
# Channel 2 max intensity: 42809
# Channel 3 max intensity: 65243
# Channel 3 max value: 42809.0 at (214, 958)
# Cropping coordinates: x1=14, x2=414, y1=758, y2=1080
# Padding applied: Left=0, Right=0, Top=0, Bottom=78
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C03-F4_B3_IM_KIF11_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C03-F5_B3_IM_KIF11_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 30823
# Channel 1 max intensity: 65246
# Channel 2 max intensity: 46026
# Channel 3 max intensity: 65535
# Channel 3 max value: 46026.0 at (1038, 580)
# Cropping coordinates: x1=838, x2=1080, y1=380, y2=780
# Padding applied: Left=0, Right=158, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C03-F5_B3_IM_KIF11_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C08-F10_B8_CM_CENPI_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 35366
# Channel 1 max intensity: 33948
# Channel 2 max intensity: 35514
# Channel 3 max intensity: 56001
# Channel 3 max value: 35514.0 at (890, 80)
# Cropping coordinates: x1=690, x2=1080, y1=0, y2=280
# Padding applied: Left=0, Right=10, Top=120, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R02-C08-F10_B8_CM_CENPI_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C06-F10_D6_IM_CAMSAP2_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 26992
# Channel 1 max intensity: 47998
# Channel 2 max intensity: 37041
# Channel 3 max intensity: 48357
# Channel 3 max value: 37041.0 at (957, 312)
# Cropping coordinates: x1=757, x2=1080, y1=112, y2=512
# Padding applied: Left=0, Right=77, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R04-C06-F10_D6_IM_CAMSAP2_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R03-C08-F8_C8_CM_CDK1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 23566
# Channel 1 max intensity: 28233
# Channel 2 max intensity: 32299
# Channel 3 max intensity: 50450
# Channel 3 max value: 32299.0 at (983, 33)
# Cropping coordinates: x1=783, x2=1080, y1=0, y2=233
# Padding applied: Left=0, Right=103, Top=167, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R03-C08-F8_C8_CM_CDK1_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R03-C11-F8_C11_CM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 34464
# Channel 1 max intensity: 37798
# Channel 2 max intensity: 13048
# Channel 3 max intensity: 21980
# Channel 3 max value: 13048.0 at (542, 32)
# Cropping coordinates: x1=342, x2=742, y1=0, y2=232
# Padding applied: Left=0, Right=0, Top=168, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R03-C11-F8_C11_CM_CDC34_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C08-F10_F8_CM_BIRC5_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C08-F10_F8_CM_BIRC5_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C08-F11_F8_CM_BIRC5_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C08-F11_F8_CM_BIRC5_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C09-F11_F9_CM_AURKC_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_72h - R06-C09-F11_F9_CM_AURKC_init.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R06-C07-F11_F7_CM_BUB1_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 31186
# Channel 1 max intensity: 27041
# Channel 2 max intensity: 23970
# Channel 3 max intensity: 38145
# Channel 3 max value: 23970.0 at (215, 150)
# Cropping coordinates: x1=15, x2=415, y1=0, y2=350
# Padding applied: Left=0, Right=0, Top=50, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R06-C07-F11_F7_CM_BUB1_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R06-C10-F4_F10_CM_AURKB_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 41806
# Channel 1 max intensity: 53557
# Channel 2 max intensity: 29103
# Channel 3 max intensity: 40658
# Channel 3 max value: 29103.0 at (385, 49)
# Cropping coordinates: x1=185, x2=585, y1=0, y2=249
# Padding applied: Left=0, Right=0, Top=151, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R06-C10-F4_F10_CM_AURKB_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R07-C03-F7_G3_IM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 28269
# Channel 1 max intensity: 36513
# Channel 2 max intensity: 50865
# Channel 3 max intensity: 65535
# Channel 3 max value: 50865.0 at (187, 421)
# Cropping coordinates: x1=0, x2=387, y1=221, y2=621
# Padding applied: Left=13, Right=0, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R07-C03-F7_G3_IM_CENPE_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R02-C10-F5_B10_CM_CENPE_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 28122
# Channel 1 max intensity: 35192
# Channel 2 max intensity: 45913
# Channel 3 max intensity: 59831
# Channel 3 max value: 45913.0 at (126, 457)
# Cropping coordinates: x1=0, x2=326, y1=257, y2=657
# Padding applied: Left=74, Right=0, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R02-C10-F5_B10_CM_CENPE_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R05-C10-F7_E10_CM_BUB3_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 39412
# Channel 1 max intensity: 31976
# Channel 2 max intensity: 22725
# Channel 3 max intensity: 40755
# Channel 3 max value: 22725.0 at (664, 0)
# Cropping coordinates: x1=464, x2=864, y1=0, y2=200
# Padding applied: Left=0, Right=0, Top=200, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R05-C10-F7_E10_CM_BUB3_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R05-C11-F11_E11_CM_BUB1B_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 33561
# Channel 1 max intensity: 33454
# Channel 2 max intensity: 34056
# Channel 3 max intensity: 48412
# Channel 3 max value: 34056.0 at (692, 78)
# Cropping coordinates: x1=492, x2=892, y1=0, y2=278
# Padding applied: Left=0, Right=0, Top=122, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_24h - R05-C11-F11_E11_CM_BUB1B_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R05-C05-F11_E5_IM_CDC20_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 25835
# Channel 1 max intensity: 23308
# Channel 2 max intensity: 35851
# Channel 3 max intensity: 44582
# Channel 3 max value: 35851.0 at (206, 59)
# Cropping coordinates: x1=6, x2=406, y1=0, y2=259
# Padding applied: Left=0, Right=0, Top=141, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R05-C05-F11_E5_IM_CDC20_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C02-F11_F2_IM_CDC34_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 27245
# Channel 1 max intensity: 39317
# Channel 2 max intensity: 63485
# Channel 3 max intensity: 65535
# Channel 3 max value: 63485.0 at (769, 61)
# Cropping coordinates: x1=569, x2=969, y1=0, y2=261
# Padding applied: Left=0, Right=0, Top=139, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R06-C02-F11_F2_IM_CDC34_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R02-C05-F11_B5_IM_APC_new.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 21311
# Channel 1 max intensity: 32923
# Channel 2 max intensity: 49975
# Channel 3 max intensity: 65535
# Channel 3 max value: 49975.0 at (913, 234)
# Cropping coordinates: x1=713, x2=1080, y1=34, y2=434
# Padding applied: Left=0, Right=33, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R02-C05-F11_B5_IM_APC_new.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C06-F10_G6_IM_CENPJ_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 24660
# Channel 1 max intensity: 29846
# Channel 2 max intensity: 65535
# Channel 3 max intensity: 65535
# Channel 3 max value: 65535.0 at (909, 546)
# Cropping coordinates: x1=709, x2=1080, y1=346, y2=746
# Padding applied: Left=0, Right=29, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R07-C06-F10_G6_IM_CENPJ_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C04-F8_D4_IM_CALM1_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 30934
# Channel 1 max intensity: 40968
# Channel 2 max intensity: 48353
# Channel 3 max intensity: 65535
# Channel 3 max value: 48353.0 at (896, 260)
# Cropping coordinates: x1=696, x2=1080, y1=60, y2=460
# Padding applied: Left=0, Right=16, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C04-F8_D4_IM_CALM1_init.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C07-F10_D7_CM_CDC27_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C07-F10_D7_CM_CDC27_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C07-F11_D7_CM_CDC27_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 0
# Channel 1 max intensity: 0
# Channel 2 max intensity: 0
# Channel 3 max intensity: 0
# Channel 3 max value: 0.0 at (0, 0)
# Skipping ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C07-F11_D7_CM_CDC27_orig.tif: No bright object found in channel 3.
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C08-F10_D8_CM_CDC20_orig.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 58500
# Channel 1 max intensity: 29254
# Channel 2 max intensity: 40457
# Channel 3 max intensity: 56342
# Channel 3 max value: 40457.0 at (1016, 425)
# Cropping coordinates: x1=816, x2=1080, y1=225, y2=625
# Padding applied: Left=0, Right=136, Top=0, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R04-C08-F10_D8_CM_CDC20_orig.tif
# Processing ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R05-C02-F8_E2_IM_CAMSAP3_init.tif with shape (16, 4, 1080, 1080)
# Channel 0 max intensity: 28927
# Channel 1 max intensity: 36566
# Channel 2 max intensity: 64811
# Channel 3 max intensity: 65535
# Channel 3 max value: 64811.0 at (361, 3)
# Cropping coordinates: x1=161, x2=561, y1=0, y2=203
# Padding applied: Left=0, Right=0, Top=197, Bottom=0
# Processed: ID0080_TK_CID_RNAiScreen_63x_ReScan_48h - R05-C02-F8_E2_IM_CAMSAP3_init.tif
# Done.
